# %%
import _pickle as pickle
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import copy
import glob
import gc

# %%
from sklearn import metrics

# %%
pd.set_option('max_rows',400)

# %%
# f = open('/data/Bodenreider_UMLS_DL/Interns/Bernal/uva_testing_data.csv','r')

# f.readline()

# testing_data = []

# for line in tqdm(f,total=173000000):
#     line = line.strip()
#     _,_,_,_,l,_,h,_,t = line.split('\t')
    
#     testing_data.append((h,t,l))

# %%
# testing_data_df = pd.DataFrame(testing_data)

# %%
# validation_set = []
# testing_set = []

# for i,g in testing_data_df.groupby(2):
    
#     perm = g.sample(len(g), random_state=np.random.RandomState(42))
    
#     val = perm[:int(len(g)*0.01)]
#     test = perm[int(len(g)*0.01):]
    
#     validation_set.append(val)
#     testing_set.append(test)

# %%
# validation_set = pd.concat(validation_set)
# testing_set = pd.concat(testing_set)

# %%
# len(validation_set)

# %%
# validation_set.groupby(2).count()

# %%
# validation_set_tuples = [(h,t,l) for h,t,l in zip(validation_set[0],validation_set[1],validation_set[2])]

# %%
# pickle.dump(validation_set_tuples, open('/data/Bodenreider_UMLS_DL/Interns/Bernal/uva_test_subset.p','wb'))

# %%
validation_set_tuples = pickle.load(open('/data/Bodenreider_UMLS_DL/Interns/Bernal/uva_test_subset.p','rb'))
pred_filename = '/data/Bodenreider_UMLS_DL/Interns/Bernal/ubert_mlm_uva_test_290020_2_predictions/umls2020_ubert_mlm_uva_test_290020_2_predictions_{}.p'

# %%
validation_set_tuples = pickle.load(open('/data/Bodenreider_UMLS_DL/Interns/Bernal/uva_test_subset.p','rb'))
pred_filename = '/data/Bodenreider_UMLS_DL/Interns/Bernal/sapbert_ubert_uva_test_1392096_predictions/umls2020_sapbert_ubert_uva_test_1392096_predictions_{}.p'

# %%
validation_set_tuples = pickle.load(open('/data/Bodenreider_UMLS_DL/Interns/Bernal/umls2020AB_sapbert_edges.p','rb'))
pred_filename = '/data/Bodenreider_UMLS_DL/Interns/Bernal/ubert_mlm_290020_2_predictions/umls2020_ubert_mlm_290020_2_predictions_{}.p'

# %%
validation_set_tuples = pickle.load(open('/data/Bodenreider_UMLS_DL/Interns/Bernal/umls2020AB_sapbert_edges.p','rb'))
pred_filename = '/data/Bodenreider_UMLS_DL/Interns/Bernal/sapbert_ubert_1392096_predictions/umls2020_sapbert_ubert_1392096_predictions_{}.p'

# %%
validation_set_tuples = pickle.load(open('/data/Bodenreider_UMLS_DL/Interns/Bernal/umls2020AB_sapbert_edges_subset.p','rb'))
pred_filename = '/data/Bodenreider_UMLS_DL/Interns/Bernal/sapbert_ubert_rw_uva_subset_1392096_predictions/umls2020_sapbert_ubert_rw_uva_subset_1392096_predictions_{}.p'

# %%
validation_set_tuples = pickle.load(open('/data/Bodenreider_UMLS_DL/Interns/Bernal/umls2020AB_sapbert_edges_subset.p','rb'))
pred_filename = '/data/Bodenreider_UMLS_DL/Interns/Bernal/ubert_mlm_rw_uva_subset_290020_2_predictions/umls2020_ubert_mlm_rw_uva_subset_290020_2_predictions_{}.p'

# %%
preds = []
i=0

while os.path.exists(pred_filename.format(i)):
    f = open(pred_filename.format(i),'rb')
    preds.append(pickle.load(f))
    i+=1
    
preds = np.vstack(preds)

# %%
len(preds)/2
# Out:
# 748101.0

# %%
len(validation_set_tuples)
# Out:
# 748101

# %%
edges_to_test = validation_set_tuples[:int(len(preds)/2)]

# %%
len(validation_set_tuples)
# Out:
# 748101

# %%
forward_preds = []
backward_preds = []

for i,p in enumerate(preds):
    if i % 2 == 0:
        forward_preds.append(p)
    else:
        backward_preds.append(p)

# %%
edges_to_test_df = pd.DataFrame(edges_to_test)

# %%
len(edges_to_test_df)
# Out:
# 748101

# %%
edges_to_test_df['forward_pred'] = np.argmax(np.vstack(forward_preds),axis=1)
edges_to_test_df['backward_pred'] = np.argmax(np.vstack(backward_preds),axis=1)

edges_to_test_df['forward_pred'] = [e for e in edges_to_test_df['forward_pred']]
edges_to_test_df['backward_pred'] = [e for e in edges_to_test_df['backward_pred']]

# %%
edges_to_test_df['f_probs'] = forward_preds
edges_to_test_df['b_probs'] = backward_preds

# %%
pd.set_option('max_colwidth',100)

# %%
#Reverse labels
edges_to_test_df[2] = [not(int(e)) for e in edges_to_test_df[2]]

# %%
edges_to_test_df
# Out:
#                                                                                                           0  \
# 0                                                                 recommended dietary changes intake sodium
# 1                                              Destruction of lesion of large intestine using thermal probe
# 2                                                                                               Meningiomas
# 3                                                                      DTaP vaccine, two pertussis antigens
# 4                                                                                    Dandie Dinmont Terrier
# ...                                                                                                     ...
# 748096                           ALCOHOL 62 mL in 100 mL TOPICAL GEL [Hand Sanitizer Vanilla Sugar Scented]
# 748097                                                 lysosomal-associated membrane protein 1 pseudogene 1
# 748098                                                           Leader Aspirin 325mg Enteric Coated Tablet
# 748099  DEXTROMETHORPHAN HYDROBROMIDE 20 mg in 10 mL / GUAIFENESIN 200 mg in 10 mL ORAL LIQUID [COUGH BE...
# 748100                                                          dexamethasone 1 MG/ML Ophthalmic Suspension
#
#                                                                                                           1  \
# 0                                                                                      Very low sodium diet
# 1                                                            Endoscopic balloon dilation of large intestine
# 2                                                                           meningioma; meningotheliomatous
# 3       acellular pertussis vaccine, inactivated / diphtheria toxoid vaccine, inactivated / tetanus toxo...
# 4                                                                                     Pterostichus dandonis
# ...                                                                                                     ...
# 748096                                            ALCOHOL 62 mL in 100 mL TOPICAL GEL [5413 hand sanitizer]
# 748097                                                                                         LAMP1P1 gene
# 748098                                                          ASPIRIN 325 mg ORAL TABLET, DELAYED RELEASE
# 748099  DEXTROMETHORPHAN HYDROBROMIDE 20 mg in 10 mL / GUAIFENESIN 200 mg in 10 mL ORAL SOLUTION [7 sele...
# 748100                                                  dexamethasone ophthalmic 0.1% ophthalmic suspension
#
#             2  forward_pred  backward_pred                  f_probs  \
# 0        True             1              1  [-1.2693753, 13.800536]
# 1        True             1              1  [-2.9219992, 6.3065124]
# 2        True             1              1  [-1.2362461, 13.836702]
# 3        True             1              0  [-1.1799781, 2.3179393]
# 4        True             1              0  [-0.30559188, 1.139416]
# ...       ...           ...            ...                      ...
# 748096  False             0              0   [4.178094, -10.707772]
# 748097  False             0              0  [2.8316758, -2.3536978]
# 748098  False             0              0   [4.347626, -10.556564]
# 748099  False             0              1   [1.150131, -0.6674626]
# 748100  False             0              0  [3.9273696, -10.996998]
#
#                         b_probs
# 0          [-1.34119, 13.71238]
# 1       [-1.4115919, 13.529308]
# 2       [-1.2002298, 13.865931]
# 3        [4.186658, -10.706172]
# 4        [1.2717767, -0.798778]
# ...                         ...
# 748096  [4.0980473, -10.108855]
# 748097  [4.0178437, -10.861731]
# 748098   [3.992342, -10.914056]
# 748099  [-1.3171297, 13.755499]
# 748100  [1.677848, -0.59046406]
#
# [748101 rows x 7 columns]

# %%
edges_to_test_df[(edges_to_test_df[2] == 0)][:100]
# Out:
#                                                                                                           0  \
# 733983                                                                                              mtGlnRS
# 733984                                         ALCOHOL 70 mL in 100 mL TOPICAL GEL [Yun Hand Sanitizer Gel]
# 733985                                     fission 1 (mitochondrial outer membrane) homolog (S. cerevisiae)
# 733986                                                               benzoyl peroxide 0.1 MG/MG Topical Gel
# 733987                                             Hizentra 20% 1g Prefilled Syringe Solution for Injection
# 733988                                                                                                CEBPA
# 733989                                  ALCOHOL 70 mL in 100 mL TOPICAL GEL [Instant Hand Sanitizer Citrus]
# 733990                         ALCOHOL 70 mL in 100 mL TOPICAL SOLUTION [Sterno performance hand sanitizer]
# 733991                                                                                      Drug, Nootropic
# 733992                      ALCOHOL 70 mL in 100 mL TOPICAL LIQUID [Lushman Blossom Refresh Viva Love Mist]
# 733993                                                    phenylephrine hydrochloride 2.5 MG/ML Nasal Spray
# 733994                                                    Premier Value Nicotine Polacrilex 2mg Chewing Gum
# 733995                                                                  ALCOHOL 70 mL in 100 mL TOPICAL GEL
# 733996                                            Premier Value Low Dose Aspirin 81mg Enteric Coated Tablet
# 733997                                                                                     Hematuria, gross
# 733998                                  CITALOPRAM HYDROBROMIDE 40 mg ORAL TABLET, FILM COATED [Citalopram]
# 733999              ALCOHOL 70 mL in 100 mL TOPICAL GEL [Perfume On Hand Sanitizer Gel Pepermint Fragrance]
# 734000                                                                                       Kaposi Sarcoma
# 734001                                  BENZALKONIUM CHLORIDE 1.3 mg in 1 mL TOPICAL LIQUID [Antibacterial]
# 734002                   ISOPROPYL ALCOHOL 0.7 mL in 1 mL TOPICAL SWAB [Sol-M Alcohol Swabs Medium Sterile]
# 734003                                                                GNP Vitamin C 250mg Gummies Soft Chew
# 734004                                                          Bleomycin/Doxorubicin/Lomustine/Vincristine
# 734005  SODIUM MONOFLUOROPHOSPHATE 0.76 g in 100 g DENTAL PASTE [UNIVERSAL ADVANCED WHITENING ANTI-CAVIT...
# 734006                                                                              Glioblastoma multiforme
# 734007             ALCOHOL 0.7 mL in 1 mL TOPICAL GEL [Nautica Non Scented Hand Sanitizer 70 Ethyl Alcohol]
# 734008                         BENZALKONIUM CHLORIDE 0.13 g in 100 g TOPICAL CLOTH [Penorra SANITARY WIPES]
# 734009                                             ALCOHOL 70 mL in 100 mL TOPICAL GEL [Hand Sanitizer ICB]
# 734010                                       ALCOHOL 62 mL in 100 mL TOPICAL GEL [SANTIZALL HAND SANITIZER]
# 734011                     ALCOHOL 62 mL in 100 mL TOPICAL GEL [POMEGRANATE VANILLA SCENTED HAND SANITIZER]
# 734012                                               downregulation of androstenedione biosynthetic process
# 734013                                                ALCOHOL 70 mL in 100 mL TOPICAL LIQUID [Pro-Sanitize]
# 734014                                                                   capsaicin 0.25 MG/ML Topical Cream
# 734015                                                                                           H2BC8 gene
# 734016                                                                                       oat kernel oil
# 734017                                      ALCOHOL 70 mL in 100 mL TOPICAL GEL [BONANGE Dr,PLUS SANITIZER]
# 734018                                                                    Acute lymphoblastic leukemia, NOS
# 734019           amylase 136,000 UNT / lipase 25,000 UNT / protease 85,000 UNT Delayed Release Oral Capsule
# 734020                                                                   general transcription factor IIA 1
# 734021                                                 olfactory receptor, family 4, subfamily F, member 12
# 734022                                                 ALCOHOL 70 mL in 100 mL TOPICAL GEL [Hand Sanitizer]
# 734023                                                                                         T Lymphocyte
# 734024  chlorpheniramine maleate 0.4 MG/ML / codeine phosphate 1 MG/ML / pseudoephedrine hydrochloride 6...
# 734025                                                                                      Haemoperitoneum
# 734026                                              protein kinase, cAMP-dependent, alpha catalytic subunit
# 734027                                                                                     Anti-Cholinergic
# 734028                                      DOCUSATE SODIUM 50 mg / SENNOSIDES 8.6 mg ORAL TABLET [SENNA-S]
# 734029                                                                        Idiopathic Pulmonary Fibrosis
# 734030                              ubiquitin-conjugating enzyme E2D 3 (UBC4/5 homolog, yeast) pseudogene 2
# 734031                                                 ALCOHOL 70 mL in 100 mL TOPICAL GEL [Hand Sanitizer]
# 734032                                                                                           Acetabulum
# 734033                     ALCOHOL 70 mL in 100 mL TOPICAL GEL [Rinse-free Disinfectant Gel Hand Sanitizer]
# 734034                                                                  ALCOHOL 70 mL in 100 mL TOPICAL GEL
# 734035                                                                                  Sickle Cell Disease
# 734036                                                                          Fuchs Endothelial Dystrophy
# 734037                                                                tight junction protein 4 (peripheral)
# 734038  Acetaminophen/Dextromethorphan Hydrobromide/Doxylamine Succinate 325 MG-15 MG-6.25 MG Oral Capsu...
# 734039                                                                                      Sanitizer, Hand
# 734040                                            ALCOHOL 650 mg in 1 mL TOPICAL GEL [Guard Hand Sanitizer]
# 734041                                 ALCOHOL 62 mL in 100 mL TOPICAL GEL [Minions Hand Sanitizer 0.84 oz]
# 734042                                                            Generalized convulsive status epilepticus
# 734043                                                                            Channel Inhibitor, Sodium
# 734044                                transcription elongation factor B (SIII), polypeptide 1 pseudogene 32
# 734045                                      ALCOHOL 70 mL in 100 mL TOPICAL GEL [Clean Care Hand Sanitizer]
# 734046  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEINE 65 mg ORAL TABLET [Headache Relief Extra Strength]
# 734047                                         RNA binding motif protein, Y chromosome, family 1, member A1
# 734048                                                     fluorouracil 10 MG/ML Topical Cream [Fluoroplex]
# 734049                                                                                      Lucilia <flies>
# 734050                                                                    Left contact lens Correction code
# 734051                                                                                          niacinamide
# 734052                                              MENTHOL 0.06 g in 1 g TOPICAL GEL [SOMBRA COOL THERAPY]
# 734053                                                               tubulin, beta polypeptide pseudogene 3
# 734054               ALCOHOL 75 mL in 100 mL TOPICAL GEL [HYTN HAND SANITIZER WITH ALOE VERA AND VITAMIN E]
# 734055                                                        vitamin B12 1 MG Extended Release Oral Tablet
# 734056                                         Walgreens Hydrocortisone Plus Maximum Strength Topical Cream
# 734057                                                                  vacuolar protein sorting 53 (yeast)
# 734058                                                             ALCOHOL 70 mL in 100 mL TOPICAL SOLUTION
# 734059                                                                            simvastatin / sitagliptin
# 734060                                    ISOPROPYL ALCOHOL 70 mL in 100 mL TOPICAL LIQUID [Hand Sanitizer]
# 734061                          ALCOHOL 62 mL in 100 mL TOPICAL GEL [My Little Pony(MLP 103)Hand Sanitizer]
# 734077         ALCOHOL 70 mL in 100 mL TOPICAL GEL [BODYCOLOGY MOISTURIZING HAND SANITIZER MIDNIGHT GARDEN]
# 734078                            ALCOHOL 70 mL in 100 mL TOPICAL GEL [Assured Instant Hand Sanitizer Aloe]
# 734079                                                                      Dextrose and Potassium Chloride
# 734080                               Aspirin 81 MG Oral Tablet, Enteric Coated [ASPIRIN ADULT LOW STRENGTH]
# 734081                                                                                              TBC1D14
# 734082  ALCOHOL 70 mL in 100 mL TOPICAL GEL [Family Dollar instant Hand Sanitizer with moisturizers and ...
#
#             2  forward_pred  backward_pred                   f_probs  \
# 733983  False             0              0   [3.9913263, -10.923195]
# 733984  False             0              0   [3.8329575, -11.068396]
# 733985  False             0              0   [3.9782524, -10.944255]
# 733986  False             0              1   [3.9864998, -10.927539]
# 733987  False             0              0   [3.9220304, -10.990307]
# 733988  False             1              0   [-1.3694708, 13.672889]
# 733989  False             0              0    [4.002026, -10.915201]
# 733990  False             0              0   [3.8201594, -11.096616]
# 733991  False             0              0   [4.0301466, -10.798787]
# 733992  False             0              0     [3.836517, -11.08483]
# 733993  False             0              0   [3.9893155, -10.879318]
# 733994  False             0              0   [3.9670994, -10.944712]
# 733995  False             0              0    [4.314966, -10.550379]
# 733996  False             0              0   [3.8943505, -10.995902]
# 733997  False             0              0   [4.1990323, -10.648493]
# 733998  False             0              0    [3.086246, -11.241991]
# 733999  False             0              0     [4.28201, -10.604374]
# 734000  False             0              1   [4.0181694, -10.900756]
# 734001  False             0              0  [4.0243273, -10.8173485]
# 734002  False             0              0   [4.0324125, -10.885451]
# 734003  False             0              0   [3.9521463, -10.970617]
# 734004  False             0              0    [4.125566, -10.785904]
# 734005  False             0              0   [3.9665923, -10.944839]
# 734006  False             0              0    [1.574017, -1.3788222]
# 734007  False             0              0   [4.0178294, -10.900649]
# 734008  False             0              0   [4.1480618, -10.766751]
# 734009  False             0              0    [3.9105465, -10.99461]
# 734010  False             0              0   [3.8707898, -10.979789]
# 734011  False             0              0   [3.9877176, -10.936055]
# 734012  False             0              0   [3.9597275, -10.930644]
# 734013  False             0              0    [3.938468, -10.969902]
# 734014  False             0              1   [3.9020753, -11.019049]
# 734015  False             0              0    [4.050745, -10.867309]
# 734016  False             0              0      [4.1756, -10.727246]
# 734017  False             0              0   [3.8607304, -11.058625]
# 734018  False             0              0    [4.196721, -10.696102]
# 734019  False             0              0    [4.0969872, -10.81235]
# 734020  False             1              0   [-0.8572271, 1.9238766]
# 734021  False             1              1   [-1.3083051, 13.763078]
# 734022  False             0              0    [3.834559, -11.052772]
# 734023  False             0              0   [3.9424264, -10.984628]
# 734024  False             0              1   [3.8161457, -11.109905]
# 734025  False             0              0   [3.9934669, -10.922073]
# 734026  False             0              0   [4.0190825, -10.833341]
# 734027  False             0              0     [3.9965644, -10.9118]
# 734028  False             0              0   [3.8736234, -10.953343]
# 734029  False             0              0    [3.927775, -10.992058]
# 734030  False             0              0   [3.5669188, -10.994361]
# 734031  False             0              0   [3.8643684, -11.031207]
# 734032  False             0              0    [4.0367255, -10.85515]
# 734033  False             0              0   [4.1352434, -10.717509]
# 734034  False             0              0   [3.8237665, -11.073953]
# 734035  False             0              0   [3.9201665, -11.004003]
# 734036  False             0              0   [3.9592948, -10.961395]
# 734037  False             0              0    [3.4945095, -9.686215]
# 734038  False             0              0    [2.1958122, -9.958043]
# 734039  False             0              0    [3.5059552, -9.660767]
# 734040  False             0              0    [3.867892, -11.051588]
# 734041  False             0              0   [4.1865983, -10.715696]
# 734042  False             0              0   [4.3420095, -5.3272943]
# 734043  False             0              0   [4.1316123, -10.747848]
# 734044  False             0              0   [3.7764044, -10.476183]
# 734045  False             0              0   [4.138014, -10.7578335]
# 734046  False             0              0  [3.8535752, -11.0594015]
# 734047  False             0              0   [3.9546819, -10.963871]
# 734048  False             0              0   [3.8873904, -11.037342]
# 734049  False             0              0   [3.9460168, -10.968798]
# 734050  False             0              0   [3.8414066, -11.063277]
# 734051  False             0              0      [3.993268, -10.9263]
# 734052  False             0              0   [4.0053706, -10.894306]
# 734053  False             0              0    [2.3694785, -1.858662]
# 734054  False             0              0   [3.9427376, -10.960018]
# 734055  False             0              0   [3.9146476, -10.957012]
# 734056  False             0              0    [1.3703579, -8.781292]
# 734057  False             0              0    [4.047408, -10.835956]
# 734058  False             0              0   [3.9115622, -10.994168]
# 734059  False             0              0   [4.2017245, -10.704669]
# 734060  False             0              1     [3.615489, -2.806055]
# 734061  False             0              0   [4.2610426, -10.605829]
# 734062  False             0              0    [3.677452, -8.8083315]
# 734063  False             0              0   [3.9517002, -10.955754]
# 734064  False             0              0   [3.8987782, -11.016171]
# 734065  False             0              0   [3.8692992, -11.005789]
# 734066  False             0              0   [3.8824313, -11.040179]
# 734067  False             0              0   [4.3002896, -10.595006]
# 734068  False             0              0    [3.878935, -11.050102]
# 734069  False             0              1    [3.882996, -11.032313]
# 734070  False             0              0   [4.0358896, -10.860033]
# 734071  False             0              0    [3.9062572, -11.01387]
# 734072  False             0              0   [4.0738616, -10.764333]
# 734073  False             0              0    [4.074438, -10.841831]
# 734074  False             0              0   [3.8186786, -11.092988]
# 734075  False             0              0   [4.0558805, -10.848753]
# 734076  False             0              0   [3.9761171, -10.853643]
# 734077  False             1              1    [-2.1399376, 8.787349]
# 734078  False             0              0   [4.0581703, -10.834104]
# 734079  False             0              0    [3.952419, -10.965322]
# 734080  False             0              0     [4.298596, -10.59045]
# 734081  False             0              0   [4.0896626, -10.697075]
# 734082  False             0              0   [3.9658093, -10.953863]
#
#                          b_probs
# 733983     [4.08271, -10.813174]
# 733984   [3.9717736, -10.936316]
# 733985    [3.9766297, -10.94574]
# 733986   [-1.3388438, 13.723759]
# 733987   [3.9144325, -10.968613]
# 733988  [1.0640337, -0.96775156]
# 733989    [4.243038, -10.643774]
# 733990       [3.9208, -11.00743]
# 733991  [4.0401406, -10.7964325]
# 733992   [3.8533597, -11.065888]
# 733993    [4.0239973, -10.85569]
# 733994   [3.9353645, -10.895442]
# 733995     [4.510603, -10.33436]
# 733996    [3.921567, -10.920298]
# 733997     [4.23059, -10.654422]
# 733998     [3.746962, -11.17779]
# 733999   [3.8490958, -11.053016]
# 734000    [0.365458, 0.39559573]
# 734001   [4.0904193, -10.785017]
# 734002    [4.047516, -10.853266]
# 734003   [3.9567823, -10.900588]
# 734004    [4.125566, -10.785904]
# 734005   [3.8973877, -11.000719]
# 734006  [0.5678207, -0.24576941]
# 734007   [4.0337787, -10.867191]
# 734008     [4.463671, -4.368069]
# 734009   [3.9899883, -10.920647]
# 734010    [4.0168247, -9.841009]
# 734011   [4.4254727, -10.397354]
# 734012   [4.032265, -10.8252535]
# 734013   [3.8587985, -11.062092]
# 734014    [-1.9346255, 2.784418]
# 734015    [4.050745, -10.867309]
# 734016      [4.1756, -10.727246]
# 734017     [4.48821, -10.264061]
# 734018    [4.1241407, -10.79101]
# 734019    [4.158739, -10.742956]
# 734020   [3.9709454, -10.945482]
# 734021    [-1.3360938, 13.73097]
# 734022   [4.1931415, -10.697894]
# 734023   [4.0028453, -10.919705]
# 734024   [-1.3523611, 13.645989]
# 734025   [3.9970064, -10.917574]
# 734026    [3.997531, -10.859578]
# 734027   [3.9403536, -10.979432]
# 734028   [3.9171622, -10.945699]
# 734029   [4.3774314, -10.503866]
# 734030    [3.465617, -10.776909]
# 734031   [4.2245026, -10.624193]
# 734032   [4.1289673, -10.787233]
# 734033    [4.099689, -10.776765]
# 734034    [4.168405, -10.707011]
# 734035   [3.9489145, -10.973499]
# 734036   [4.2203097, -10.682127]
# 734037    [3.7163923, -8.731797]
# 734038   [3.8394325, -10.822125]
# 734039    [3.5934129, -9.236109]
# 734040   [4.0436153, -10.869283]
# 734041    [4.463294, -10.378744]
# 734042    [4.1194787, -6.673488]
# 734043   [3.9552174, -10.870704]
# 734044     [4.00941, -10.902498]
# 734045    [4.185863, -10.486813]
# 734046   [3.9286013, -10.972273]
# 734047    [3.434012, -10.724395]
# 734048   [2.0845764, -1.2545806]
# 734049     [4.305698, -5.579262]
# 734050   [3.9724007, -10.946713]
# 734051   [3.9777327, -10.923962]
# 734052    [4.029774, -10.882575]
# 734053   [4.0310683, -10.882662]
# 734054   [3.8620076, -11.029904]
# 734055    [3.958305, -10.962604]
# 734056     [3.828519, -6.324593]
# 734057   [3.9625566, -10.944472]
# 734058   [4.0408187, -10.879103]
# 734059     [4.24742, -10.654565]
# 734060     [-1.346645, 13.71223]
# 734061    [4.465348, -10.391614]
# 734062   [4.0755205, -6.9623055]
# 734063    [3.902802, -11.004422]
# 734064   [3.9575682, -10.953767]
# 734065   [2.5429742, -1.8417609]
# 734066   [4.1093745, -10.808175]
# 734067    [4.362362, -10.505553]
# 734068   [4.1794753, -6.2723765]
# 734069   [0.6475299, 0.83790636]
# 734070   [4.1883817, -10.708031]
# 734071   [3.8875735, -11.035001]
# 734072   [4.0407147, -10.861133]
# 734073     [4.17542, -10.738548]
# 734074    [3.8920865, -11.02816]
# 734075    [4.040851, -10.862481]
# 734076   [3.9216673, -10.997358]
# 734077    [-3.1087565, 5.196583]
# 734078    [3.872246, -11.037355]
# 734079      [3.50869, -9.814985]
# 734080     [4.383861, -10.50949]
# 734081    [4.047871, -10.808719]
# 734082   [4.0322275, -10.883701]

# %%
edges_to_test_df[(edges_to_test_df[2] != edges_to_test_df['forward_pred']) & (edges_to_test_df[2] == 1)][:10]
# Out:
#                                                             0  \
# 11                                 Antodynerus punctatipennis
# 12                             opiate alkaloid hydrochlorides
# 13  carbohydrate (N-acetylglucosamine 6-O) sulfotransferase 6
# 20                            ANKRD26-like family C, member 2
# 22                                                     Rodent
# 24                                                Endotrophin
# 26                                       Monarthrum fasciatum
# 27                        solute carrier family 25, member 47
# 32                                     printor protein, human
# 35                                         Gesneria prasinata
#
#                                          1     2  forward_pred  backward_pred  \
# 11                    Orthoperus punctatus  True             0              0
# 12                            morphine HCl  True             0              1
# 13  carbohydrate sulfotransferase 3, human  True             0              0
# 20                                 ANKRD28  True             0              0
# 22                                 animals  True             0              0
# 24                         Cardiotrophin-1  True             0              0
# 26                   Oplegnathus fasciatus  True             0              0
# 27                                 SLC25A7  True             0              0
# 32          proline-rich protein 11, human  True             0              0
# 35                       Gyraulus prashadi  True             0              0
#
#                      f_probs                    b_probs
# 11  [0.89501464, -0.4774303]  [0.48210016, 0.015357983]
# 12    [3.2233772, -2.853614]    [-3.0491898, 5.9641023]
# 13     [3.744505, -8.582532]     [3.9083548, -7.715111]
# 20   [4.0659947, -10.843598]     [4.0107965, -10.89679]
# 22   [4.4419518, -4.5000105]    [3.8289416, -3.6415198]
# 24    [4.126797, -10.776625]    [4.0485067, -10.861971]
# 26    [4.188382, -10.694934]    [4.2590036, -10.617833]
# 27   [3.9946408, -10.920219]    [3.9045942, -11.014159]
# 32    [4.4074287, -4.632481]     [3.6076925, -9.446375]
# 35  [3.6829228, -10.7000065]     [3.588484, -10.409935]

# %%
edges_to_test_df.groupby(2).count()
# Out:
#             0       1  forward_pred  backward_pred  f_probs  b_probs
# 2
# False  733981  733983        733983         733983   733983   733983
# True    14118   14118         14118          14118    14118    14118

# %%
edges_to_test_df.groupby('forward_pred').count()
# Out:
#                    0       1       2  backward_pred  f_probs  b_probs
# forward_pred
# 0             189767  189769  189769         189769   189769   189769
# 1             558332  558332  558332         558332   558332   558332

# %%
edges_to_test_df.groupby('backward_pred').count()
# Out:
#                     0       1       2  forward_pred  f_probs  b_probs
# backward_pred
# 0              191194  191196  191196        191196   191196   191196
# 1              556905  556905  556905        556905   556905   556905

# %%
labels = [int(e) for e in edges_to_test_df[2]]

# %%
f_p, f_r, forward_ubert_f1, f_s = metrics.precision_recall_fscore_support(labels, edges_to_test_df['forward_pred'], pos_label=0, average='binary')
b_p, b_r, backward_ubert_f1, b_s = metrics.precision_recall_fscore_support(labels, edges_to_test_df['backward_pred'], pos_label=0, average='binary')

# %%
forward_ubert_f1, f_p, f_r
# Out:
# (0.1791234948193783, 0.09938472056058793, 0.9061481796288426)

# %%
backward_ubert_f1, b_p, b_r
# Out:
# (0.12185238220481799, 0.0654250088913994, 0.88603201586627)

# %%
f = open('/data/Bodenreider_UMLS_DL/thilini/EXPERIMENTS/datasets/2020AA-ACTIVE_ALL_MODEL_GENTEST_DS_TEST_DS_SHUF_dedup.RRF','r')

test_set = []

for i, line in tqdm(enumerate(f),total=173000000):
    line = line.strip()
    
#     if i > 100000:
#         break
    
    line_list = line.split('|')
    test_set.append(line_list)
# Out:
#  99%|███████████████████████████████████████████████████████████████████████████████▌| 171991918/173000000 [05:55<00:02, 484468.27it/s]

# %%
f = open('/data/Bodenreider_UMLS_DL/thilini/EXPERIMENTS/6_SAPBERT_SP/test/correct_metrics_predictions_checkpoint-1392096.txt','r')
f = open('/data/Bodenreider_UMLS_DL/thilini/EXPERIMENTS/1_UMLS_ONLY/testing/correct_metrics_predictions_checkpoint-290020_2.txt','r')

preds = []


for i, line in tqdm(enumerate(f),total=173000000):
    line = line.strip()
    
#     if i > 100000:
#         break
        
    preds.append([float(f) for f in line.split()])
# Out:
#  99%|███████████████████████████████████████████████████████████████████████████████▌| 171991918/173000000 [17:09<00:06, 167078.73it/s]

# %%
f = open('/data/Bodenreider_UMLS_DL/thilini/EXPERIMENTS/6_SAPBERT_SP/test/correct_metrics_labels_checkpoint-986068.txt','r')
# f = open('/data/Bodenreider_UMLS_DL/thilini/EXPERIMENTS/1_UMLS_ONLY/testing/correct_metrics_labels_checkpoint-435030_2.txt','r')

true = []

for i, line in tqdm(enumerate(f),total=173000000):
    line = line.strip()
    
#     if i > 100000:
#         break
    
    true.append(line)
# Out:
#  99%|███████████████████████████████████████████████████████████████████████████████▌| 171991918/173000000 [03:51<00:01, 742297.51it/s]

# %%
aui_dict = pickle.load(open('/data/Bodenreider_UMLS_DL/thilini/EXPERIMENTS/aui_vec/aui_vec.pkl','rb'))

# %%
true = [int(l) for l in true]

# %%
#Alternative
test_set_df = pd.DataFrame(test_set)
l_ = [int(e) for e in test_set_df[3]]
l_ = np.array(l_)
ls = (l_ + 1) % 2
true = ls

# %%
preds_ = np.argmax(preds, axis=1)

# %%
sum(true),sum(preds_),len(true), len(preds_)
# Out:
# (166410710, 165921774, 171991918, 171991918)

# %%
p, r, f1, _ = metrics.precision_recall_fscore_support(true, preds_, pos_label=0, average='binary')

# %%
p,r,f1
# Out:
# (0.8950508812636843, 0.9757724492618802, 0.9336701936246622)

# %%
test_set_df['labels'] = true

# %%
test_set_df['preds'] = preds_

# %%
test_set_df['probs'] = preds

# %%
aui_info = []

with open('/data/Bodenreider_UMLS_DL/UMLS_VERSIONS/2020AA-ACTIVE/META/MRCONSO.RRF','r') as fp:
    
    for line in fp.readlines():
        line = line.split('|')
        cui = line[0]
        aui = line[7]
        string = line[-5]
        
        aui_info.append({'AUI':aui, 'CUI':cui, 'STR':string})
        
cui2sg = {}

with open('/data/Bodenreider_UMLS_DL/UMLS_VERSIONS/2020AA-ACTIVE/META/MRSTY.RRF','r') as fp:
    
    for line in fp.readlines():
        line = line.split('|')
        cui = line[0]
        sg = line[3]
        cui2sg[cui] = sg
        
cui2aui = {}
aui2cui = {}
aui2str = {}
aui2sg = {}

cui_sg = []
cui_aui = []

for tup in tqdm(aui_info):
    aui = tup['AUI']
    
    cui = tup['CUI']
    string = tup['STR']
    sg = cui2sg[cui]

    auis = cui2aui.get(cui, [])
    auis.append(aui)
    cui2aui[cui] = auis

    aui2cui[aui] = cui
    aui2str[aui] = string
    aui2sg[aui] = sg

    cui_sg.append((cui, sg))
    cui_aui.append((cui, aui))
        
semgroups = pd.read_csv('SemGroups.txt',sep='|',header=None)

semtype2sg = {}

for i, row in semgroups.iterrows():
    
    st = row[3]
    sg = row[1]
    
    semtype2sg[st] = sg
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14770662/14770662 [00:49<00:00, 297781.09it/s]

# %%
aui2str['A27392030'], aui2str['A30080569']
# Out:
# ('OXYGEN 990 mL in 1 L RESPIRATORY (INHALATION) GAS',
#  'OXYGEN 99 L in 100 L RESPIRATORY (INHALATION) GAS')

# %%
subset = []

for i,g in test_set_df.groupby('labels'):
    
    ss = g[:int(len(g)*0.0001)]
    subset.append(ss)
    
subset = pd.concat(subset)

# %%
subset.groupby('labels').count()
# Out:
#             0      1      2      3  preds  probs
# labels
# 0         558    558    558    558    558    558
# 1       16641  16641  16641  16641  16641  16641

# %%
subset['aui1'] = [aui2str[a] for a in subset[1]]
subset['aui2'] = [aui2str[a] for a in subset[2]]

# %%
subset_tuples = []

for i, row in subset.iterrows():
    
    subset_tuples.append((row['aui1'],row['aui2'],row['labels']))

# %%
# pickle.dump(subset_tuples, open('/data/Bodenreider_UMLS_DL/Interns/Bernal/uva_test_subset.p','wb'))

# %%
len(subset_tuples)
# Out:
# 17199

# %%
subset
# Out:
#       0           1          2  3  labels  preds                 probs  \
# 10        A30080569  A27392030  1       0      0   [9.83976, -5.19342]
# 23        A18609178  A11919293  1       0      0   [10.09789, -4.9064]
# 89        A20995170  A30930630  1       0      0   [5.99245, -5.43056]
# 99        A12107333  A18464903  1       0      1    [0.00327, 0.02176]
# 119       A28944944  A31462601  1       0      0   [9.88996, -5.15059]
# ...   ..        ...        ... ..     ...    ...                   ...
# 17208     A19314985  A20897915  0       1      1  [-2.89513, 11.96102]
# 17209     A26465514  A28763437  0       1      1   [-2.89377, 11.9591]
# 17210      A2979722  A15489415  0       1      1  [-2.91038, 11.98175]
# 17211     A11713707   A0062665  0       1      1  [-2.90471, 11.97332]
# 17212     A11280544  A28066517  0       1      1  [-2.90882, 11.97948]
#
#                                                                                   aui1  \
# 10                                   OXYGEN 99 L in 100 L RESPIRATORY (INHALATION) GAS
# 23                                                                        chlorambucil
# 89     Aspirin 325 mg in 325 mg ORAL TABLET [Value PharmaPain Reliever Extra Strength]
# 99                                                  SPINOCEREBELLAR ATAXIA, X-LINKED 3
# 119                          toldimfos sodium 200 MG/ML Injectable Solution [Phos-Aid]
# ...                                                                                ...
# 17208                                                                     eprinomectin
# 17209                                                                    Regurgitation
# 17210                                                             Reticular dysgenesia
# 17211                                                                        COQ9 gene
# 17212                                                                 TG-Phos compound
#
#                                                                       aui2
# 10                       OXYGEN 990 mL in 1 L RESPIRATORY (INHALATION) GAS
# 23                       para-N,N-di(b-chloroethyl)aminophenylbutyric acid
# 89                ASPIRIN 325 mg ORAL TABLET, COATED [aspirin pain relief]
# 99                                     Spinocerebellar ataxia, X-linked, 3
# 119     TOLDIMFOS SODIUM 200 mg in 1 mL INTRAMUSCULAR INJECTION [Phos-Aid]
# ...                                                                    ...
# 17208                                                eprinomectin 50 MG/ML
# 17209  mitral regurgitation due to acute myocardial infarction (diagnosis)
# 17210                                    Nervous system of pectoral girdle
# 17211                                                                Genes
# 17212                                              Trichodactylus kensleyi
#
# [17199 rows x 9 columns]

# %%
aui_dict['A30080569']
# Out:
# [3208, 2883, 54, 194, 549, 54, 1351, 12, 3617, 13, 1482]
